# %% [markdown]
# # 神经网络八股总览
#
# ## 六步法
#
# import
#
# train, test
#
# Sequential / Class
#
# model.compile
#
# model.fit
#
# model.summary

# %%
import tensorflow as tf

# 下载数据集
fashion = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion.load_data()
# 归一化
x_train, x_test = x_train / 255.0, x_test / 255.0

np.random.seed(116)
np.random.shuffle(x_train)
np.random.seed(116)
np.random.shuffle(y_train)
tf.random.set_seed(116)

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'，
    tf.keras.layers.Dense(3, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1),
                         loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                         metrics=['sparse_categorical_accuracy'])

model.fit(x_train, y_train, batch_size=32, epochs=500, validation_split=0.2, validation_freq=20)

model.summary()
# Out:
# Epoch 1/500
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3173 - sparse_categorical_accuracy: 0.3417
# Epoch 2/500
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0797 - sparse_categorical_accuracy: 0.6167
# Epoch 3/500
# 4/4 [==============================] - 0s 669us/step - loss: 0.8429 - sparse_categorical_accuracy: 0.6250
# Epoch 4/500
# 4/4 [==============================] - 0s 896us/step - loss: 0.7448 - sparse_categorical_accuracy: 0.6667
# Epoch 5/500
# 4/4 [==============================] - 0s 665us/step - loss: 0.9843 - sparse_categorical_accuracy: 0.6417
# Epoch 6/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7808 - sparse_categorical_accuracy: 0.6583
# Epoch 7/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.5961 - sparse_categorical_accuracy: 0.7250
# Epoch 8/500
# 4/4 [==============================] - 0s 703us/step - loss: 0.5824 - sparse_categorical_accuracy: 0.7250
# Epoch 9/500
# 4/4 [==============================] - 0s 996us/step - loss: 0.6016 - sparse_categorical_accuracy: 0.7000
# Epoch 10/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.6707 - sparse_categorical_accuracy: 0.6500
# Epoch 11/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7967 - sparse_categorical_accuracy: 0.6667
# Epoch 12/500
# 4/4 [==============================] - 0s 999us/step - loss: 0.5385 - sparse_categorical_accuracy: 0.7500
# Epoch 13/500
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0675 - sparse_categorical_accuracy: 0.5833
# Epoch 14/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.5119 - sparse_categorical_accuracy: 0.7333
# Epoch 15/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6831 - sparse_categorical_accuracy: 0.6667
# Epoch 16/500
# 4/4 [==============================] - 0s 998us/step - loss: 0.5969 - sparse_categorical_accuracy: 0.7667
# Epoch 17/500
# 4/4 [==============================] - 0s 665us/step - loss: 0.5559 - sparse_categorical_accuracy: 0.7250
# Epoch 18/500
# 4/4 [==============================] - 0s 668us/step - loss: 0.6521 - sparse_categorical_accuracy: 0.7667
# Epoch 19/500
# 4/4 [==============================] - 0s 1000us/step - loss: 0.5902 - sparse_categorical_accuracy: 0.6833
# Epoch 20/500
# 4/4 [==============================] - 0s 52ms/step - loss: 0.4782 - sparse_categorical_accuracy: 0.8000 - val_loss: 0.7740 - val_sparse_categorical_accuracy: 0.5333
# Epoch 21/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4589 - sparse_categorical_accuracy: 0.8333
# Epoch 22/500
# 4/4 [==============================] - 0s 999us/step - loss: 0.6620 - sparse_categorical_accuracy: 0.7167
# Epoch 23/500
# 4/4 [==============================] - 0s 676us/step - loss: 0.4497 - sparse_categorical_accuracy: 0.8583
# Epoch 24/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.7418 - sparse_categorical_accuracy: 0.6917
# Epoch 25/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4873 - sparse_categorical_accuracy: 0.7333
# Epoch 26/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.7408 - sparse_categorical_accuracy: 0.7083
# Epoch 27/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6502 - sparse_categorical_accuracy: 0.7750
# Epoch 28/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6749 - sparse_categorical_accuracy: 0.6667
# Epoch 29/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5382 - sparse_categorical_accuracy: 0.7833
# Epoch 30/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6266 - sparse_categorical_accuracy: 0.7000
# Epoch 31/500
# 4/4 [==============================] - 0s 786us/step - loss: 0.5041 - sparse_categorical_accuracy: 0.7917
# Epoch 32/500
# 4/4 [==============================] - 0s 993us/step - loss: 0.6933 - sparse_categorical_accuracy: 0.7250
# Epoch 33/500
# 4/4 [==============================] - 0s 695us/step - loss: 0.5518 - sparse_categorical_accuracy: 0.7667
# Epoch 34/500
# 4/4 [==============================] - 0s 669us/step - loss: 0.4097 - sparse_categorical_accuracy: 0.9000
# Epoch 35/500
# 4/4 [==============================] - 0s 999us/step - loss: 0.4705 - sparse_categorical_accuracy: 0.7917
# Epoch 36/500
# 4/4 [==============================] - 0s 665us/step - loss: 0.4490 - sparse_categorical_accuracy: 0.8583
# Epoch 37/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.4172 - sparse_categorical_accuracy: 0.9333
# Epoch 38/500
# 4/4 [==============================] - 0s 1000us/step - loss: 0.6989 - sparse_categorical_accuracy: 0.6583
# Epoch 39/500
# 4/4 [==============================] - 0s 998us/step - loss: 0.5124 - sparse_categorical_accuracy: 0.7833
# Epoch 40/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3984 - sparse_categorical_accuracy: 0.9333 - val_loss: 0.5433 - val_sparse_categorical_accuracy: 0.6000
# Epoch 41/500
# 4/4 [==============================] - 0s 668us/step - loss: 0.5434 - sparse_categorical_accuracy: 0.7333
# Epoch 42/500
# 4/4 [==============================] - 0s 668us/step - loss: 0.6159 - sparse_categorical_accuracy: 0.7000
# Epoch 43/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6999 - sparse_categorical_accuracy: 0.7167
# Epoch 44/500
# 4/4 [==============================] - 0s 664us/step - loss: 0.4048 - sparse_categorical_accuracy: 0.9333
# Epoch 45/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.3924 - sparse_categorical_accuracy: 0.9500
# Epoch 46/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3944 - sparse_categorical_accuracy: 0.9333
# Epoch 47/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4063 - sparse_categorical_accuracy: 0.9083
# Epoch 48/500
# 4/4 [==============================] - 0s 665us/step - loss: 0.5635 - sparse_categorical_accuracy: 0.7583
# Epoch 49/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4108 - sparse_categorical_accuracy: 0.9333
# Epoch 50/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3884 - sparse_categorical_accuracy: 0.9583
# Epoch 51/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3835 - sparse_categorical_accuracy: 0.9417
# Epoch 52/500
# 4/4 [==============================] - 0s 665us/step - loss: 0.4042 - sparse_categorical_accuracy: 0.9083
# Epoch 53/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4400 - sparse_categorical_accuracy: 0.8500
# Epoch 54/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7052 - sparse_categorical_accuracy: 0.6417
# Epoch 55/500
# 4/4 [==============================] - 0s 668us/step - loss: 0.4013 - sparse_categorical_accuracy: 0.8833
# Epoch 56/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3983 - sparse_categorical_accuracy: 0.8917
# Epoch 57/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5127 - sparse_categorical_accuracy: 0.8000
# Epoch 58/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.5093 - sparse_categorical_accuracy: 0.8000
# Epoch 59/500
# 4/4 [==============================] - 0s 779us/step - loss: 0.4715 - sparse_categorical_accuracy: 0.8083
# Epoch 60/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5407 - sparse_categorical_accuracy: 0.9000 - val_loss: 0.4260 - val_sparse_categorical_accuracy: 0.9333
# Epoch 61/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.4227 - sparse_categorical_accuracy: 0.8833
# Epoch 62/500
# 4/4 [==============================] - 0s 665us/step - loss: 0.4420 - sparse_categorical_accuracy: 0.8583
# Epoch 63/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6500 - sparse_categorical_accuracy: 0.7167
# Epoch 64/500
# 4/4 [==============================] - 0s 999us/step - loss: 0.4293 - sparse_categorical_accuracy: 0.8667
# Epoch 65/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.3863 - sparse_categorical_accuracy: 0.9167
# Epoch 66/500
# 4/4 [==============================] - 0s 555us/step - loss: 0.3802 - sparse_categorical_accuracy: 0.9250
# Epoch 67/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4052 - sparse_categorical_accuracy: 0.8667
# Epoch 68/500
# 4/4 [==============================] - 0s 666us/step - loss: 0.5520 - sparse_categorical_accuracy: 0.7250
# Epoch 69/500
# 4/4 [==============================] - 0s 669us/step - loss: 0.4788 - sparse_categorical_accuracy: 0.8167
# Epoch 70/500
# 4/4 [==============================] - 0s 675us/step - loss: 0.3761 - sparse_categorical_accuracy: 0.9333
# Epoch 71/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4550 - sparse_categorical_accuracy: 0.8250
# Epoch 72/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.4004 - sparse_categorical_accuracy: 0.9250
# Epoch 73/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5146 - sparse_categorical_accuracy: 0.8167
# Epoch 74/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.
500
# 4/4 [==============================] - 0s 667us/step - loss: 0.3681 - sparse_categorical_accuracy: 0.9250
# Epoch 397/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3659 - sparse_categorical_accuracy: 0.9000
# Epoch 398/500
# 4/4 [==============================] - 0s 666us/step - loss: 0.3437 - sparse_categorical_accuracy: 0.9667
# Epoch 399/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.3917 - sparse_categorical_accuracy: 0.9083
# Epoch 400/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3787 - sparse_categorical_accuracy: 0.9250 - val_loss: 0.5941 - val_sparse_categorical_accuracy: 0.6000
# Epoch 401/500
# 4/4 [==============================] - 0s 669us/step - loss: 0.3651 - sparse_categorical_accuracy: 0.9333
# Epoch 402/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3480 - sparse_categorical_accuracy: 0.9583
# Epoch 403/500
# 4/4 [==============================] - 0s 1000us/step - loss: 0.3813 - sparse_categorical_accuracy: 0.9167
# Epoch 404/500
# 4/4 [==============================] - 0s 664us/step - loss: 0.4448 - sparse_categorical_accuracy: 0.8583
# Epoch 405/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.3864 - sparse_categorical_accuracy: 0.9083
# Epoch 406/500
# 4/4 [==============================] - 0s 807us/step - loss: 0.3440 - sparse_categorical_accuracy: 0.9583
# Epoch 407/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4250 - sparse_categorical_accuracy: 0.8667
# Epoch 408/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.3375 - sparse_categorical_accuracy: 0.9667
# Epoch 409/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3470 - sparse_categorical_accuracy: 0.9333
# Epoch 410/500
# 4/4 [==============================] - 0s 807us/step - loss: 0.3442 - sparse_categorical_accuracy: 0.9500
# Epoch 411/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.3907 - sparse_categorical_accuracy: 0.8583
# Epoch 412/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.3829 - sparse_categorical_accuracy: 0.8750
# Epoch 413/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3658 - sparse_categorical_accuracy: 0.8917
# Epoch 414/500
# 4/4 [==============================] - 0s 666us/step - loss: 0.3384 - sparse_categorical_accuracy: 0.9583
# Epoch 415/500
# 4/4 [==============================] - 0s 668us/step - loss: 0.3447 - sparse_categorical_accuracy: 0.9667
# Epoch 416/500
# 4/4 [==============================] - 0s 837us/step - loss: 0.3389 - sparse_categorical_accuracy: 0.9750
# Epoch 417/500
# 4/4 [==============================] - 0s 1000us/step - loss: 0.3484 - sparse_categorical_accuracy: 0.9750
# Epoch 418/500
# 4/4 [==============================] - 0s 665us/step - loss: 0.3718 - sparse_categorical_accuracy: 0.9167
# Epoch 419/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3435 - sparse_categorical_accuracy: 0.9500
# Epoch 420/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3400 - sparse_categorical_accuracy: 0.9500 - val_loss: 0.3493 - val_sparse_categorical_accuracy: 1.0000
# Epoch 421/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3376 - sparse_categorical_accuracy: 0.9667
# Epoch 422/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.3501 - sparse_categorical_accuracy: 0.9750
# Epoch 423/500
# 4/4 [==============================] - 0s 674us/step - loss: 0.4595 - sparse_categorical_accuracy: 0.8250
# Epoch 424/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3583 - sparse_categorical_accuracy: 0.9333
# Epoch 425/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3593 - sparse_categorical_accuracy: 0.9417
# Epoch 426/500
# 4/4 [==============================] - 0s 669us/step - loss: 0.4827 - sparse_categorical_accuracy: 0.8000
# Epoch 427/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4092 - sparse_categorical_accuracy: 0.8917
# Epoch 428/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3592 - sparse_categorical_accuracy: 0.9250
# Epoch 429/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3744 - sparse_categorical_accuracy: 0.9000
# Epoch 430/500
# 4/4 [==============================] - 0s 665us/step - loss: 0.4432 - sparse_categorical_accuracy: 0.8750
# Epoch 431/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3755 - sparse_categorical_accuracy: 0.9167
# Epoch 432/500
# 4/4 [==============================] - 0s 1000us/step - loss: 0.3350 - sparse_categorical_accuracy: 0.9667
# Epoch 433/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3608 - sparse_categorical_accuracy: 0.9417
# Epoch 434/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3540 - sparse_categorical_accuracy: 0.9417
# Epoch 435/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3831 - sparse_categorical_accuracy: 0.9167
# Epoch 436/500
# 4/4 [==============================] - 0s 672us/step - loss: 0.3791 - sparse_categorical_accuracy: 0.8750
# Epoch 437/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.
500
# 4/4 [==============================] - 0s 665us/step - loss: 0.3371 - sparse_categorical_accuracy: 0.9583
# Epoch 477/500
# 4/4 [==============================] - 0s 718us/step - loss: 0.4072 - sparse_categorical_accuracy: 0.8917
# Epoch 478/500
# 4/4 [==============================] - 0s 333us/step - loss: 0.4168 - sparse_categorical_accuracy: 0.8750
# Epoch 479/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.4617 - sparse_categorical_accuracy: 0.8333
# Epoch 480/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3497 - sparse_categorical_accuracy: 0.9417 - val_loss: 0.3175 - val_sparse_categorical_accuracy: 1.0000
# Epoch 481/500
# 4/4 [==============================] - 0s 916us/step - loss: 0.3413 - sparse_categorical_accuracy: 0.9667
# Epoch 482/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3415 - sparse_categorical_accuracy: 0.9667
# Epoch 483/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3437 - sparse_categorical_accuracy: 0.9583
# Epoch 484/500
# 4/4 [==============================] - 0s 957us/step - loss: 0.3377 - sparse_categorical_accuracy: 0.9500
# Epoch 485/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4217 - sparse_categorical_accuracy: 0.8583
# Epoch 486/500
# 4/4 [==============================] - 0s 915us/step - loss: 0.3618 - sparse_categorical_accuracy: 0.9417
# Epoch 487/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3622 - sparse_categorical_accuracy: 0.9083
# Epoch 488/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3756 - sparse_categorical_accuracy: 0.8917
# Epoch 489/500
# 4/4 [==============================] - 0s 677us/step - loss: 0.3968 - sparse_categorical_accuracy: 0.9000
# Epoch 490/500
# 4/4 [==============================] - 0s 655us/step - loss: 0.3435 - sparse_categorical_accuracy: 0.9583
# Epoch 491/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.3394 - sparse_categorical_accuracy: 0.9750
# Epoch 492/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3348 - sparse_categorical_accuracy: 0.9833
# Epoch 493/500
# 4/4 [==============================] - 0s 666us/step - loss: 0.3447 - sparse_categorical_accuracy: 0.9333
# Epoch 494/500
# 4/4 [==============================] - 0s 669us/step - loss: 0.3433 - sparse_categorical_accuracy: 0.9333
# Epoch 495/500
# 4/4 [==============================] - 0s 667us/step - loss: 0.3357 - sparse_categorical_accuracy: 0.9583
# Epoch 496/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3445 - sparse_categorical_accuracy: 0.9583
# Epoch 497/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3435 - sparse_categorical_accuracy: 0.9333
# Epoch 498/500
# 4/4 [==============================] - 0s 668us/step - loss: 0.3406 - sparse_categorical_accuracy: 0.9667
# Epoch 499/500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3649 - sparse_categorical_accuracy: 0.9333
# Epoch 500/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3888 - sparse_categorical_accuracy: 0.9250 - val_loss: 0.3516 - val_sparse_categorical_accuracy: 0.8667
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 自制数据集

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import os

train_path = './mnist_image_label/mnist_train_jpg_60000/'
train_txt = './mnist_image_label/mnist_train_jpg_60000.txt'
x_train_savepath = './mnist_image_label/mnist_x_train.npy'
y_train_savepath = './mnist_image_label/mnist_y_train.npy'

test_path = './mnist_image_label/mnist_test_jpg_10000/'
test_txt = './mnist_image_label/mnist_test_jpg_10000.txt'
x_test_savepath = './mnist_image_label/mnist_x_test.npy'
y_test_savepath = './mnist_image_label/mnist_y_test.npy'


def generateds(path, txt):
    f = open(txt, 'r')  # 以只读形式打开txt文件
    contents = f.readlines()  # 读取文件中所有行
    f.close()  # 关闭txt文件
    x, y_ = [], []  # 建立空列表
    for content in contents:  # 逐行取出
        value = content.split()  # 以空格分开，图片路径为value[0] , 标签为value[1] , 存入列表
        img_path = path + value[0]  # 拼出图片路径和文件名
        img = Image.open(img_path)  # 读入图片
        img = np.array(img.convert('L'))  # 图片变为8位宽灰度值的np.array格式
        img = img / 255.  # 数据归一化 （实现预处理）
        x.append(img)  # 归一化后的数据，贴到列表x
        y_.append(value[1])  # 标签贴到列表y_
        print('loading : ' + content)  # 打印状态提示

    x = np.array(x)  # 变为np.array格式
    y_ = np.array(y_)  # 变为np.array格式
    y_ = y_.astype(np.int64)  # 变为64位整型
    return x, y_  # 返回输入特征x，返回标签y_


if os.path.exists(x_train_savepath) and os.path.exists(y_train_savepath) and os.path.exists(
        x_test_savepath) and os.path.exists(y_test_savepath):
    print('-------------Load Datasets-----------------')
    x_train_save = np.load(x_train_savepath)
    y_train = np.load(y_train_savepath)
    x_test_save = np.load(x_test_savepath)
    y_test = np.load(y_test_savepath)
    x_train = np.reshape(x_train_save, (len(x_train_save), 28, 28))
    x_test = np.reshape(x_test_save, (len(x_test_save), 28, 28))
else:
    print('-------------Generate Datasets-----------------')
    x_train, y_train = generateds(train_path, train_txt)
    x_test, y_test = generateds(test_path, test_txt)

    print('-------------Save Datasets-----------------')
    x_train_save = np.reshape(x_train, (len(x_train), -1))
    x_test_save = np.reshape(x_test, (len(x_test), -1))
    np.save(x_train_savepath, x_train_save)
    np.save(y_train_savepath, y_train)
    np.save(x_test_savepath, x_test_save)
    np.save(y_test_savepath, y_test)

# %% [markdown]
# ## 数据增强

# %%
# image_gen_train = tf.keras.preprocessing.image.imageDataGeneratot(
#             rescale=所有数据将乘以该值
#             rotation_range=随机旋转角度数范围
#             width_shift_range=随机宽度偏移量
#             height_shift_range=随机高度偏移量
#             horizontal_flip=是否随机水平翻转
#             zoom_range=随机缩放的范围[1-n,1+n]
#             )

# 显示原始图像和增强后的图像
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)

# 数据增强函数设置
image_gen_train = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=45,
    width_shift_range=.15,
    height_shift_range=.15,
    horizontal_flip=False,
    zoom_range=0.5
)

# 数据增强操作
image_gen_train.fit(x_train)

print("xtrain",x_train.shape)
x_train_subset1 = np.squeeze(x_train[:12])
print("xtrain_subset1",x_train_subset1.shape)
print("xtrain",x_train.shape)
x_train_subset2 = x_train[:12]  # 一次显示12张图片
print("xtrain_subset2",x_train_subset2.shape)

fig = plt.figure(figsize=(20, 2))
plt.set_cmap('gray')
# 显示原始图片
for i in range(0, len(x_train_subset1)):
    ax = fig.add_subplot(1, 12, i + 1)
    ax.imshow(x_train_subset1[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# 显示增强后的图片
fig = plt.figure(figsize=(20, 2))
for x_batch in image_gen_train.flow(x_train_subset2, batch_size=12, shuffle=False):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i + 1)
        ax.imshow(np.squeeze(x_batch[i]))
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['sparse_categorical_accuracy'])
# 增强数据喂入
model.fit(image_gen_train.flow(x_train, y_train, batch_size=32), epochs=5, validation_data=(x_test, y_test),
          validation_freq=1)
model.summary()

# %% [markdown]
# ## 断点续训

# %%
import tensorflow as tf
import os

mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['sparse_categorical_accuracy'])


checkpoint_save_path = "./checkpoint/mnist.ckpt"
# 读取模型
if os.path.exists(checkpoint_save_path + '.index'):
    print('-------------load the model-----------------')
    model.load_weights(checkpoint_save_path)

# 保存模型 
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,
                                                 save_best_only=True)

history = model.fit(x_train, y_train, batch_size=32, epochs=5, validation_data=(x_test, y_test), validation_freq=1,
                    callbacks=[cp_callback])
model.summary()

# %% [markdown]
# ## 参数提取

# %% [markdown]
# 提取可训练参数
#
#     model.trainable_variables 返回模型中可训练的参数
#
# 设置print输出格式
#
#     np.set_printoptions(threshold=超过多少省略显示)
#
#     np.set_printoptions(threshold=np.inf) # np.inf 表示无限大
#
#     print(model.trainable_variables)
#     file = open('./weights.txt', 'w')
#     for v in model.trainable_variables:
#         file.write(str(v.name) + '\n')
#         file.write(str(v.shape) + '\n')
#         file.write(str(v.numpy()) + '\n')
#     file.close()

# %%
import tensorflow as tf
import os
import numpy as np
np.set_printoptions(threshold=np.inf)
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['sparse_categorical_accuracy'])
checkpoint_save_path = "./checkpoint/mnist.ckpt"
if os.path.exists(checkpoint_save_path + '.index'):
    print('-------------load the model-----------------')
    model.load_weights(checkpoint_save_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,
                                                 save_best_only=True)
history = model.fit(x_train, y_train, batch_size=32, epochs=5, validation_data=(x_test, y_test), validation_freq=1,
                    callbacks=[cp_callback])
model.summary()
print(model.trainable_variables)
file = open('./weights.txt', 'w')
for v in model.trainable_variables:
    file.write(str(v.name) + '\n')
    file.write(str(v.shape) + '\n')
    file.write(str(v.numpy()) + '\n')
file.close()

# %% [markdown]
# ## acc/loss可视化

# %% [markdown]
#     history = model.fit(训练集数据，训练集标签，batch_size=, epochs=, validation_split=用作测试数据的比例，validation_data=测试集,validation_freq=测试频率)
#
#     hitory:
#     训练集loss: loss
#     测试集loss: val_loss
#     训练集准确度：sparse_categorical_accuracy
#     测试集准确率：val_sparse+categorical_accuracy
#
#        acc = history.history['sparse_categorical_accuracy']
#
#        val_acc = history.history['val_sparse_caregorical_accuracy']
#
#        loss = history.history['loss']
#
#        val_loss = history.history['val_loss']

# %%
# 显示训练集和验证集的acc和loss曲线
acc = history.history['sparse_categorical_accuracy']
val_acc = history.history['val_sparse_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## 应用程序

# %% [markdown]
# 前向传播执行应用
#
#     predict(输入特征， batch_size=整数)
#         返回前向传播计算结果
#
# 复现模型（前向传播）：
#       model= tf.keras.models.Sequestial([
#           ### 与训练模型一致
#       ])
#
# 加载参数：
#     model.load_weights(model_save_path)
#
# 预测结果
#     result = model.predict(x_predict)
#      `

# %%
from PIL import Image
import numpy as np
import tensorflow as tf

model_save_path = './checkpoint/mnist.ckpt'

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')])
    
model.load_weights(model_save_path)

preNum = int(input("input the number of test pictures:"))

for i in range(preNum):
    image_path = input("the path of test picture:")
    img = Image.open(image_path)
    img = img.resize((28, 28), Image.ANTIALIAS)
    img_arr = np.array(img.convert('L'))

    img_arr = 255 - img_arr
                
    img_arr = img_arr / 255.0
    print("img_arr:",img_arr.shape)
    x_predict = img_arr[tf.newaxis, ...]
    print("x_predict:",x_predict.shape)
    result = model.predict(x_predict)
    
    pred = tf.argmax(result, axis=1)
    
    print('\n')
    tf.print(pred)
